# %% [markdown]
# ### training the BrainAlignNet

# %%
import os
os.chdir("../scripts")

# %%
from train import set_GPU, fit_deepreg
# Out:
# 2025-02-04 00:02:33.110586: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-04 00:02:33.110630: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-04 00:02:33.112211: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
base = "/home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet"
config_path = f"{base}/demo_notebook/demo_network_config.yaml"
log_dir = f"{base}/demo_notebook"
experiment_name = "test_full_network"
max_epochs = 2
initial_epoch = 1

# %%
set_GPU(3)
fit_deepreg(
    config_path,
    log_dir,
    experiment_name,
    max_epochs,
    initial_epoch)
# Out:
# 2025-02-04 00:02:35 | WARNING  | Log directory /home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet/demo_notebook/test_full_network exists already.
# Built inputs.
# Built control points.
# Concatenated images.
# {'extract_levels': ListWrapper([0, 1, 2, 3]), 'name': 'local', 'num_channel_initial': 16}
# Built backbone.
# Built DDF.
# Built warping.
# Built outputs.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738627403.400462 1887349 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1/2
# ...

# %% [markdown]
# ### register test (unseen) images with checkpoint (weights of the trained network)

# %%
from register import set_GPU, register

# %%
model_config_path = config_path
model_ckpt_path = f"{base}/demo_notebook/test_full_network/save/ckpt-2"

# %%
set_GPU(3)
registered_outputs = register(model_config_path, model_ckpt_path)
# Out:
#   0%|          | 0/96 [00:00<?, ?it/s]
# 2025-02-04 00:05:25 | WARNING  | Log directory outputs/outputs exists already.
# 2025-02-04 00:05:25 | WARNING  | Using customized configuration. The code might break if the config doesn't match the saved model.
# Built inputs.
# Built control points.
# Concatenated images.
# {'extract_levels': ListWrapper([0, 1, 2, 3]), 'name': 'local', 'num_channel_initial': 16}
# Built backbone.
# Built DDF.
# Built warping.
#   1%|          | 1/96 [00:09<14:37,  9.24s/it]
# 2025-02-04 00:05:34 | WARNING  | Log directory outputs/outputs exists already.
# 2025-02-04 00:05:34 | WARNING  | Using customized configuration. The code might break if the config doesn't match the saved model.
# Built inputs.
# Built control points.
# Concatenated images.
# {'extract_levels': ListWrapper([0, 1, 2, 3]), 'name': 'local', 'num_channel_initial': 16}
# Built backbone.
# Built DDF.
# Built warping.
# ...

# %% [markdown]
# #### plot registered outputs

# %%
import matplotlib.pyplot as plt

# %%
registered_outputs['2022-01-17-01'].keys()
# Out:
# dict_keys(['1002to1197', '1015to1127', '1025to1514', '103to642', '108to1357', '1124to1347', '116to740', '11to719', '1213to1522', '1215to1229', '1270to1455', '1276to1510', '1290to1311', '1290to1391', '1292to1328', '1320to1586', '1336to1455', '1372to1465', '1391to1404', '141to1358', '158to535', '167to983', '175to555', '18to605', '198to1183', '199to1565', '19to517', '209to455', '222to1408', '230to866', '241to1502', '266to509', '266to844', '273to770', '274to995', '298to1579', '304to933', '319to1097', '330to1585', '332to1558', '355to740', '371to682', '374to950', '385to672', '404to660', '406to997', '412to643', '415to1189', '419to1333', '449to1563', '44to824', '483to754', '493to1397', '500to933', '50to276', '516to1018', '517to1119', '521to712', '530to614', '533to895', '548to1066', '548to1241', '549to840', '54to891', '558to1082', '564to567', '569to775', '580to713', '584to1052', '592to1279', '598to690', '619to1329', '62to336', '631to851', '649to1412', '662to1583', '671to974', '680to1506', '72
# ...

# %%
registration_prob = '1002to1197'
output_dict = registered_outputs['2022-01-17-01'][registration_prob]
warped_moving_image = output_dict['warped_moving_image']
warped_moving_roi = output_dict['warped_moving_roi']
warped_moving_centroids = output_dict['warped_moving_centroids']

# %%
output_dict.keys()
# Out:
# dict_keys(['warped_moving_image', 'warped_moving_roi', 'warped_moving_centroids'])

# %%
warped_moving_image.shape, warped_moving_roi.shape, warped_moving_centroids.shape
# Out:
# ((284, 120, 64), (284, 120, 64), (200, 3))

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 12))
axes[0].imshow(warped_moving_image.max(2));
axes[0].set_title("warped moving image", fontsize=20);
axes[1].imshow(warped_moving_roi.max(2));
axes[1].set_title("warped moving roi", fontsize=20);

axes[2].imshow(warped_moving_roi.max(2));
axes[2].set_title("warped moving roi", fontsize=20);

xs = [x for (x, _, _) in warped_moving_centroids]
ys = [y for (_, y, _) in warped_moving_centroids]


axes[2].scatter(ys, xs, s=5, c='w');
axes[2].set_title("warped moving centroids", fontsize=20);
axes[2].set_xlim(0, 120);
axes[2].set_ylim(0, 284);
axes[2].invert_yaxis()

# %%
import h5py
test_path = "/store1/PublishedData/Data/prj_register/BrainAlignNet/train/nonaugmented/2022-01-17-01"

with h5py.File(os.path.join(test_path, "moving_images.h5"), 'r') as f:
    mov_img = f[registration_prob][:]

with h5py.File(os.path.join(test_path, "fixed_images.h5"), 'r') as f:
    fix_img = f[registration_prob][:]

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 12))
axes[0].imshow(mov_img.max(2))
axes[0].set_title("moving image", fontsize=20)
axes[1].imshow(warped_moving_image.max(2))
axes[1].set_title("warped moving image", fontsize=20)

axes[2].imshow(fix_img.max(2))

# xs = [x for (x, _, _) in warped_moving_centroids]
# ys = [y for (_, y, _) in warped_moving_centroids]


# axes[2].scatter(ys, xs, s=5, c='w')
axes[2].set_title("fixed image", fontsize=20)
axes[2].set_xlim(0, 120)
axes[2].set_ylim(0, 284)
axes[2].invert_yaxis()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
