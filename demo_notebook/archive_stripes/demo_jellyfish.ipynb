# %% [markdown]
# ### training the BrainAlignNet

# %%
import os
os.chdir("../../scripts")

# %%
from train import set_GPU, fit_deepreg
# import train
# Out:
# 2025-02-11 20:47:46.856301: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-11 20:47:46.856347: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-11 20:47:46.857932: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
base = "/home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet"
config_path = f"{base}/demo_notebook/demo_jelly_config.yaml"
log_dir = f"{base}/demo_notebook"
experiment_name = "test_jelly"
max_epochs = 5
initial_epoch = 1

# %%
base = "/home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet"
config_path = f"{base}/demo_notebook/demo_jelly_config_mixedlabs.yaml"
log_dir = f"{base}/demo_notebook"
experiment_name = "test_jelly"
max_epochs = 300
initial_epoch = 1

# %%
base = "/home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet"
config_path = f"{base}/demo_notebook/demo_data_config.yaml"
log_dir = f"{base}/demo_notebook"
experiment_name = "demo_data"
max_epochs = 300
initial_epoch = 1

# %%
base = "/home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet"
config_path = f"{base}/demo_notebook/archive/demo_data_config_padded.yaml"
log_dir = f"{base}/demo_notebook/archive"
experiment_name = "demo_data_padded_lockedZ"
max_epochs = 1500
initial_epoch = 0

# %%
# %env DEEPREG_LOG_LEVEL=0
import tensorflow as tf
# tf.debugging.enable_check_numerics()
# tf.config.experimental_run_functions_eagerly(True)
set_GPU(3)
fit_deepreg(
    config_path,
    log_dir,
    experiment_name,
    max_epochs,
    initial_epoch)
# Out:
# env: DEEPREG_LOG_LEVEL=0
# Built inputs.
# Built control points.
# Concatenated images.
# {'extract_levels': ListWrapper([0, 1, 2, 3]), 'name': 'local', 'num_channel_initial': 16}
# Built backbone.
# Built DDF.
# Built warping.
# Built outputs.
# 2025-02-11 20:48:48 | WARNING  | The configuration for loss regularization is not defined. Therefore it is not used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1739306976.891848  759316 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1/1500
# 1/1 [==============================] - 6s 6s/step - loss: -98.3076 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9881 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8076 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 50.0027 - loss/label_CentroidDistance_weighted: 0.5000 - metric/ddf_mean: 0.0014 - metric/ddf_min: -0.0493 - metric/ddf_max: 0.1547 - val_loss: -98.3555 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8555 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0000 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -1.5634e-04 - val_metric/ddf_min: -4.5637e-04 - val_metric/ddf_max: 1.8089e-04
# Epoch 2/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.3120 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9881 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8121 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 50.0092 - loss/label_CentroidDistance_weighted: 0.5001 - metric/ddf_mean: 0.0034 - metric/ddf_min: -0.1049 - metric/ddf_max: 0.3631 - val_loss: -98.3596 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8596 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0000 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -2.4660e-04 - val_metric/ddf_min: -7.8417e-04 - val_metric/ddf_max: 3.1427e-04
# Epoch 3/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.3129 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9881 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8130 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 50.0081 - loss/label_CentroidDistance_weighted: 0.5001 - metric/ddf_mean: 0.0056 - metric/ddf_min: -0.1626 - metric/ddf_max: 0.5143 - val_loss: -98.3344 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8344 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0001 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -3.4153e-04 - val_metric/ddf_min: -0.0012 - val_metric/ddf_max: 4.6769e-04
# Epoch 4/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.3190 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9882 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8191 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 50.0097 - loss/label_CentroidDistance_weighted: 0.5001 - metric/ddf_mean: 0.0082 - metric/ddf_min: -0.2158 - metric/ddf_max: 0.6408 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0002 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -4.3358e-04 - val_metric/ddf_min: -0.0016 - val_metric/ddf_max: 6.4375e-04
# Epoch 5/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.3169 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9882 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8170 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 50.0071 - loss/label_CentroidDistance_weighted: 0.5001 - metric/ddf_mean: 0.0103 - metric/ddf_min: -0.2877 - metric/ddf_max: 0.8607 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0003 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -5.2709e-04 - val_metric/ddf_min: -0.0020 - val_metric/ddf_max: 8.3143e-04
# Epoch 6/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.3197 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9882 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8197 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 50.0029 - loss/label_CentroidDistance_weighted: 0.5000 - metric/ddf_mean: 0.0123 - metric/ddf_min: -0.3620 - metric/ddf_max: 1.1658 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0004 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -6.3169e-04 - val_metric/ddf_min: -0.0024 - val_metric/ddf_max: 0.0010
# Epoch 7/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.3227 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9882 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8226 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9979 - loss/label_CentroidDistance_weighted: 0.5000 - metric/ddf_mean: 0.0148 - metric/ddf_min: -0.4525 - metric/ddf_max: 1.4148 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0005 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -7.5310e-04 - val_metric/ddf_min: -0.0029 - val_metric/ddf_max: 0.0012
# Epoch 8/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.3293 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8292 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9937 - loss/label_CentroidDistance_weighted: 0.4999 - metric/ddf_mean: 0.0178 - metric/ddf_min: -0.5355 - metric/ddf_max: 1.6394 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0005 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -8.9500e-04 - val_metric/ddf_min: -0.0035 - val_metric/ddf_max: 0.0013
# Epoch 9/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.3405 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9884 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8404 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9900 - loss/label_CentroidDistance_weighted: 0.4999 - metric/ddf_mean: 0.0208 - metric/ddf_min: -0.6110 - metric/ddf_max: 1.9933 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0005 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0011 - val_metric/ddf_min: -0.0040 - val_metric/ddf_max: 0.0015
# Epoch 10/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.3519 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9885 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8518 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9867 - loss/label_CentroidDistance_weighted: 0.4999 - metric/ddf_mean: 0.0243 - metric/ddf_min: -0.6557 - metric/ddf_max: 2.3199 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0004 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0012 - val_metric/ddf_min: -0.0046 - val_metric/ddf_max: 0.0016
# Epoch 11/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.3601 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8599 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9807 - loss/label_CentroidDistance_weighted: 0.4998 - metric/ddf_mean: 0.0278 - metric/ddf_min: -0.7056 - metric/ddf_max: 2.6519 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0002 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0015 - val_metric/ddf_min: -0.0052 - val_metric/ddf_max: 0.0017
# Epoch 12/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.3780 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9888 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8777 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9756 - loss/label_CentroidDistance_weighted: 0.4998 - metric/ddf_mean: 0.0317 - metric/ddf_min: -0.7457 - metric/ddf_max: 3.0106 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 50.0000 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0017 - val_metric/ddf_min: -0.0057 - val_metric/ddf_max: 0.0017
# Epoch 13/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.3953 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9890 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8951 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9714 - loss/label_CentroidDistance_weighted: 0.4997 - metric/ddf_mean: 0.0356 - metric/ddf_min: -0.7617 - metric/ddf_max: 3.4482 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9997 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0019 - val_metric/ddf_min: -0.0063 - val_metric/ddf_max: 0.0017
# Epoch 14/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.4097 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9891 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9093 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9671 - loss/label_CentroidDistance_weighted: 0.4997 - metric/ddf_mean: 0.0405 - metric/ddf_min: -0.7648 - metric/ddf_max: 3.8449 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9994 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0022 - val_metric/ddf_min: -0.0070 - val_metric/ddf_max: 0.0016
# Epoch 15/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.4170 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9892 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9166 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9601 - loss/label_CentroidDistance_weighted: 0.4996 - metric/ddf_mean: 0.0452 - metric/ddf_min: -0.7393 - metric/ddf_max: 4.3033 - val_loss: -98.3255 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9883 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8255 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9990 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0025 - val_metric/ddf_min: -0.0076 - val_metric/ddf_max: 0.0015
# Epoch 16/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.4282 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9893 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9279 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9710 - loss/label_CentroidDistance_weighted: 0.4997 - metric/ddf_mean: 0.0518 - metric/ddf_min: -0.6303 - metric/ddf_max: 4.7355 - val_loss: -98.3196 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9882 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8196 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9985 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0029 - val_metric/ddf_min: -0.0082 - val_metric/ddf_max: 0.0014
# Epoch 17/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.4300 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9893 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9295 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9494 - loss/label_CentroidDistance_weighted: 0.4995 - metric/ddf_mean: 0.0556 - metric/ddf_min: -0.6897 - metric/ddf_max: 5.3501 - val_loss: -98.3542 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9885 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8541 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9979 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0032 - val_metric/ddf_min: -0.0089 - val_metric/ddf_max: 0.0013
# Epoch 18/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.4292 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9893 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9287 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9510 - loss/label_CentroidDistance_weighted: 0.4995 - metric/ddf_mean: 0.0638 - metric/ddf_min: -0.5674 - metric/ddf_max: 5.6635 - val_loss: -98.3556 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8555 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9973 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0036 - val_metric/ddf_min: -0.0095 - val_metric/ddf_max: 0.0012
# Epoch 19/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.4367 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9894 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9361 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9481 - loss/label_CentroidDistance_weighted: 0.4995 - metric/ddf_mean: 0.0698 - metric/ddf_min: -0.4503 - metric/ddf_max: 6.2838 - val_loss: -98.3557 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8557 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9966 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0040 - val_metric/ddf_min: -0.0102 - val_metric/ddf_max: 0.0011
# Epoch 20/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.4328 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9893 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9322 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9381 - loss/label_CentroidDistance_weighted: 0.4994 - metric/ddf_mean: 0.0747 - metric/ddf_min: -0.3378 - metric/ddf_max: 7.0823 - val_loss: -98.3556 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8556 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9958 - val_loss/label_CentroidDistance_weighted: 0.5000 - val_metric/ddf_mean: -0.0044 - val_metric/ddf_min: -0.0109 - val_metric/ddf_max: 9.1554e-04
# Epoch 21/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.4224 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9892 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9217 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9307 - loss/label_CentroidDistance_weighted: 0.4993 - metric/ddf_mean: 0.0820 - metric/ddf_min: -0.2883 - metric/ddf_max: 7.5429 - val_loss: -98.3555 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8555 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9949 - val_loss/label_CentroidDistance_weighted: 0.4999 - val_metric/ddf_mean: -0.0049 - val_metric/ddf_min: -0.0117 - val_metric/ddf_max: 7.1325e-04
# Epoch 22/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.4203 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9892 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9196 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9313 - loss/label_CentroidDistance_weighted: 0.4993 - metric/ddf_mean: 0.0915 - metric/ddf_min: -0.2256 - metric/ddf_max: 7.8248 - val_loss: -98.3555 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8555 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9939 - val_loss/label_CentroidDistance_weighted: 0.4999 - val_metric/ddf_mean: -0.0055 - val_metric/ddf_min: -0.0125 - val_metric/ddf_max: 4.6321e-04
# Epoch 23/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.4191 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9892 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9184 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9289 - loss/label_CentroidDistance_weighted: 0.4993 - metric/ddf_mean: 0.1003 - metric/ddf_min: -0.2261 - metric/ddf_max: 8.1089 - val_loss: -98.3555 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8555 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9928 - val_loss/label_CentroidDistance_weighted: 0.4999 - val_metric/ddf_mean: -0.0061 - val_metric/ddf_min: -0.0133 - val_metric/ddf_max: 1.4659e-04
# Epoch 24/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.4267 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9893 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9258 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9126 - loss/label_CentroidDistance_weighted: 0.4991 - metric/ddf_mean: 0.1068 - metric/ddf_min: -0.2453 - metric/ddf_max: 8.4402 - val_loss: -98.3555 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8555 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9915 - val_loss/label_CentroidDistance_weighted: 0.4999 - val_metric/ddf_mean: -0.0067 - val_metric/ddf_min: -0.0143 - val_metric/ddf_max: 0.0000e+00
# Epoch 25/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.4233 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9892 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9224 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9068 - loss/label_CentroidDistance_weighted: 0.4991 - metric/ddf_mean: 0.1140 - metric/ddf_min: -0.2713 - metric/ddf_max: 9.1369 - val_loss: -98.3556 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8555 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9901 - val_loss/label_CentroidDistance_weighted: 0.4999 - val_metric/ddf_mean: -0.0074 - val_metric/ddf_min: -0.0153 - val_metric/ddf_max: 0.0000e+00
# Epoch 26/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.4234 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9892 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9225 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9062 - loss/label_CentroidDistance_weighted: 0.4991 - metric/ddf_mean: 0.1250 - metric/ddf_min: -0.3000 - metric/ddf_max: 9.2258 - val_loss: -98.3556 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8555 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9886 - val_loss/label_CentroidDistance_weighted: 0.4999 - val_metric/ddf_mean: -0.0082 - val_metric/ddf_min: -0.0164 - val_metric/ddf_max: 0.0000e+00
# Epoch 27/1500
# 1/1 [==============================] - 3s 3s/step - loss: -98.4277 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9893 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9267 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.9049 - loss/label_CentroidDistance_weighted: 0.4990 - metric/ddf_mean: 0.1340 - metric/ddf_min: -0.3278 - metric/ddf_max: 9.6497 - val_loss: -98.3556 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8555 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9870 - val_loss/label_CentroidDistance_weighted: 0.4999 - val_metric/ddf_mean: -0.0090 - val_metric/ddf_min: -0.0176 - val_metric/ddf_max: 0.0000e+00
# Epoch 28/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.4236 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9892 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9225 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.8928 - loss/label_CentroidDistance_weighted: 0.4989 - metric/ddf_mean: 0.1404 - metric/ddf_min: -0.3564 - metric/ddf_max: 10.3760 - val_loss: -98.3556 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8555 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9853 - val_loss/label_CentroidDistance_weighted: 0.4999 - val_metric/ddf_mean: -0.0099 - val_metric/ddf_min: -0.0189 - val_metric/ddf_max: 0.0000e+00
# Epoch 29/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.4279 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9893 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9267 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 49.8750 - loss/label_CentroidDistance_weighted: 0.4988 - metric/ddf_mean: 0.1500 - metric/ddf_min: -0.3862 - metric/ddf_max: 10.2388 - val_loss: -98.3556 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9886 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.8555 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 49.9836 - val_loss/label_CentroidDistance_weighted: 0.4998 - val_metric/ddf_mean: -0.0108 - val_metric/ddf_min: -0.0202 - val_metric/ddf_max: 0.0000e+00
# Epoch 30/1500
# ...
# Epoch 1492/1500
# 1/1 [==============================] - 5s 5s/step - loss: -98.9992 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9900 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0048 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 0.5616 - loss/label_CentroidDistance_weighted: 0.0056 - metric/ddf_mean: 1.6388 - metric/ddf_min: -91.0916 - metric/ddf_max: 42.5772 - val_loss: -98.9814 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9907 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0697 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 8.8243 - val_loss/label_CentroidDistance_weighted: 0.0882 - val_metric/ddf_mean: 1.6299 - val_metric/ddf_min: -92.8180 - val_metric/ddf_max: 41.3525
# Epoch 1493/1500
# 1/1 [==============================] - 4s 4s/step - loss: -99.0011 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9901 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0069 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 0.5742 - loss/label_CentroidDistance_weighted: 0.0057 - metric/ddf_mean: 1.6359 - metric/ddf_min: -90.0834 - metric/ddf_max: 42.4359 - val_loss: -98.9929 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9908 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0846 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 9.1741 - val_loss/label_CentroidDistance_weighted: 0.0917 - val_metric/ddf_mean: 1.6124 - val_metric/ddf_min: -92.6557 - val_metric/ddf_max: 40.9999
# Epoch 1494/1500
# 1/1 [==============================] - 3s 3s/step - loss: -99.0003 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9901 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0111 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 1.0777 - loss/label_CentroidDistance_weighted: 0.0108 - metric/ddf_mean: 1.6373 - metric/ddf_min: -92.9927 - metric/ddf_max: 42.3968 - val_loss: -99.0237 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9908 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0846 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 6.0905 - val_loss/label_CentroidDistance_weighted: 0.0609 - val_metric/ddf_mean: 1.5760 - val_metric/ddf_min: -92.7220 - val_metric/ddf_max: 41.7293
# Epoch 1495/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.9959 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9900 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0040 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 0.8110 - loss/label_CentroidDistance_weighted: 0.0081 - metric/ddf_mean: 1.6323 - metric/ddf_min: -91.0598 - metric/ddf_max: 42.5909 - val_loss: -99.0223 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9908 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0804 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 5.8025 - val_loss/label_CentroidDistance_weighted: 0.0580 - val_metric/ddf_mean: 1.5583 - val_metric/ddf_min: -92.9417 - val_metric/ddf_max: 42.0475
# Epoch 1496/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.9884 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9900 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9983 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 0.9894 - loss/label_CentroidDistance_weighted: 0.0099 - metric/ddf_mean: 1.6313 - metric/ddf_min: -90.7063 - metric/ddf_max: 42.4201 - val_loss: -98.9806 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9907 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0652 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 8.4550 - val_loss/label_CentroidDistance_weighted: 0.0845 - val_metric/ddf_mean: 1.5796 - val_metric/ddf_min: -92.7014 - val_metric/ddf_max: 41.5258
# Epoch 1497/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.9860 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9900 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9956 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 0.9646 - loss/label_CentroidDistance_weighted: 0.0096 - metric/ddf_mean: 1.6342 - metric/ddf_min: -92.2348 - metric/ddf_max: 42.1856 - val_loss: -98.9810 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9907 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0714 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 9.0397 - val_loss/label_CentroidDistance_weighted: 0.0904 - val_metric/ddf_mean: 1.5513 - val_metric/ddf_min: -92.0023 - val_metric/ddf_max: 41.4853
# Epoch 1498/1500
# 1/1 [==============================] - 5s 5s/step - loss: -98.9823 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9899 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9881 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 0.5832 - loss/label_CentroidDistance_weighted: 0.0058 - metric/ddf_mean: 1.6337 - metric/ddf_min: -90.2003 - metric/ddf_max: 42.2554 - val_loss: -98.9657 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9907 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0683 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 10.2581 - val_loss/label_CentroidDistance_weighted: 0.1026 - val_metric/ddf_mean: 1.5141 - val_metric/ddf_min: -91.3762 - val_metric/ddf_max: 40.9333
# Epoch 1499/1500
# 1/1 [==============================] - 5s 5s/step - loss: -98.9729 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9898 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9774 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 0.4460 - loss/label_CentroidDistance_weighted: 0.0045 - metric/ddf_mean: 1.6321 - metric/ddf_min: -90.0756 - metric/ddf_max: 42.4258 - val_loss: -98.9444 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9907 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0681 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 12.3760 - val_loss/label_CentroidDistance_weighted: 0.1238 - val_metric/ddf_mean: 1.5041 - val_metric/ddf_min: -92.5229 - val_metric/ddf_max: 40.4430
# Epoch 1500/1500
# 1/1 [==============================] - 4s 4s/step - loss: -98.9603 - metric/moving_image_mean: 0.2716 - metric/moving_image_min: 0.0000e+00 - metric/moving_image_max: 1.0000 - metric/fixed_image_mean: 0.2718 - metric/fixed_image_min: 0.0000e+00 - metric/fixed_image_max: 1.0000 - loss/image_LocalNormalizedCrossCorrelationLoss: -0.9897 - loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -98.9702 - metric/moving_label_mean: 291.7778 - metric/moving_label_min: -1.0000 - metric/moving_label_max: 990.0000 - metric/fixed_label_mean: 277.8889 - metric/fixed_label_min: -1.0000 - metric/fixed_label_max: 900.0000 - loss/label_CentroidDistance: 0.9851 - loss/label_CentroidDistance_weighted: 0.0099 - metric/ddf_mean: 1.6347 - metric/ddf_min: -93.1382 - metric/ddf_max: 42.5789 - val_loss: -98.9268 - val_metric/moving_image_mean: 0.2716 - val_metric/moving_image_min: 0.0000e+00 - val_metric/moving_image_max: 1.0000 - val_metric/fixed_image_mean: 0.2718 - val_metric/fixed_image_min: 0.0000e+00 - val_metric/fixed_image_max: 1.0000 - val_loss/image_LocalNormalizedCrossCorrelationLoss: -0.9907 - val_loss/image_LocalNormalizedCrossCorrelationLoss_weighted: -99.0667 - val_metric/moving_label_mean: 291.7778 - val_metric/moving_label_min: -1.0000 - val_metric/moving_label_max: 990.0000 - val_metric/fixed_label_mean: 277.8889 - val_metric/fixed_label_min: -1.0000 - val_metric/fixed_label_max: 900.0000 - val_loss/label_CentroidDistance: 13.9910 - val_loss/label_CentroidDistance_weighted: 0.1399 - val_metric/ddf_mean: 1.4334 - val_metric/ddf_min: -92.5041 - val_metric/ddf_max: 40.2803

# %% [markdown]
# ### register test (unseen) images with checkpoint (weights of the trained network)

# %%
from register import set_GPU, register
# Out:
# 2025-02-11 22:50:01.272281: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-11 22:50:01.308996: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-11 22:50:01.309037: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-11 22:50:01.310583: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-11 22:50:01.317673: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-11 22:50:02.070728: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model_config_path = config_path
# model_ckpt_path = f"/home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet/demo_notebook/demo_data/save/ckpt-300"
model_ckpt_path = f"/home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet/demo_notebook/archive_stripes/demo_data_padded_lockedZ/save/ckpt-1500"
# model_ckpt_path = f"/home/brian/notebooks/brian/PBrainAlign_and_Jelly/private_BrainAlignNet/demo_notebook/demo_data_padded/save/ckpt-1381"

# %%
set_GPU(3)
registered_outputs = register(model_config_path, model_ckpt_path)
# Out:
# /home/brian/data4/brian/PBnJ/test_data/stripes_padded/fixed_images.h5
#   0%|          | 0/1 [00:00<?, ?it/s]2025-02-11 22:37:32.143541: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46576 MB memory:  -> device: 3, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:c2:00.0, compute capability: 8.9
# 2025-02-11 22:37:33 | WARNING  | Log directory outputs/outputs exists already.
# 2025-02-11 22:37:33 | WARNING  | Using customized configuration. The code might break if the config doesn't match the saved model.
# Built inputs.
# Built control points.
# Concatenated images.
# {'extract_levels': ListWrapper([0, 1, 2, 3]), 'name': 'local', 'num_channel_initial': 16}
# Built backbone.
# Built DDF.
# Built warping.
# 2025-02-11 22:37:35 | WARNING  | The configuration for loss regularization is not defined. Therefore it is not used.
# 2025-02-11 22:37:35.284216: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 100%|██████████| 1/1 [00:15<00:00, 15.58s/it]
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.24
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.25
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.26
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.27
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.28
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.29
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.30
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.31
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.32
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.33
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.34
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.35
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.36
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.37
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.38
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.39
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.40
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.41
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.42
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.43
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.44
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.45
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.46
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.47
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.48
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.49
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.50
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.51
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.52
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.53
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.54
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.55
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.56
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.57
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.58
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.59
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.60
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.61
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.62
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.63
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.64
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.65
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.66
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.67
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.68
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.69
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.70
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.71
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.72
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.73
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.74
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.75
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.76
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.77
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.78
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.79
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.80
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.81
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.82
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.83
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.84
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.85
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.86
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.87
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.88
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.89
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.90
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.91
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.92
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.93
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.94
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.95
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.96
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.97
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.98
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.99
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.100
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.101
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.102
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.103
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.104
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.105
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.106
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.107
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.108
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.109
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.110
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.111
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.112
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.113
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.114
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.115
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.116
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.117
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.118
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.119
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.120
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.121
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.122
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.123
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.124
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.125
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.126
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.127
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.128
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.129
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.130
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.131
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.132
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.133
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.134
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.135
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.136
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.137
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.138
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.139
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.140
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.141
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.142
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.143
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.144
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.145
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.146
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.147
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.148

# %% [markdown]
# #### plot registered outputs

# %%
import matplotlib.pyplot as plt

# %%
experiment = 'stripes_padded'
# experiment = 'stripes'
registered_outputs.keys()
# Out:
# dict_keys(['stripes_padded'])

# %%
registration_prob = '1to2'
output_dict = registered_outputs[experiment][registration_prob]
warped_moving_image = output_dict['warped_moving_image']
warped_moving_roi = output_dict['warped_moving_roi']
warped_moving_centroids = output_dict['warped_moving_centroids']

# %%
output_dict.keys()
# Out:
# dict_keys(['warped_moving_image', 'warped_moving_roi', 'warped_moving_centroids'])

# %%
warped_moving_image.shape, warped_moving_roi.shape, warped_moving_centroids.shape
# Out:
# ((1080, 1080, 2), (1080, 1080, 2), (200, 3))

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 12))
if len(warped_moving_image.shape) == 2:
    axes[0].imshow(warped_moving_image);
else:
    axes[0].imshow(warped_moving_image.max(2));
axes[0].set_title("warped moving image", fontsize=20);
axes[1].imshow(warped_moving_roi.max(2));
axes[1].set_title("warped moving roi", fontsize=20);

axes[2].imshow(warped_moving_roi.max(2));
axes[2].set_title("warped moving roi", fontsize=20);

xs = [x for (x, _, _) in warped_moving_centroids]
ys = [y for (_, y, _) in warped_moving_centroids]


axes[2].scatter(ys, xs, s=5, c='r');
axes[2].set_title("warped moving centroids", fontsize=20);
# axes[2].set_xlim(0, 120);
# axes[2].set_ylim(0, 284);
axes[2].invert_yaxis()

# %%
import h5py
test_path = "/home/brian/data4/brian/PBnJ/test_data/stripes"

with h5py.File(os.path.join(test_path, "moving_images.h5"), 'r') as f:
    mov_img = f[registration_prob][:]

with h5py.File(os.path.join(test_path, "fixed_images.h5"), 'r') as f:
    fix_img = f[registration_prob][:]


with h5py.File(os.path.join(test_path, "fixed_labels.h5"), 'r') as f:
    fix_labs = f[registration_prob][:]

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 12))
if len(warped_moving_image.shape) == 2:
    axes[0].imshow(mov_img)
else:
    axes[0].imshow(mov_img.max(2))
axes[0].set_title("moving image", fontsize=20)
if len(warped_moving_image.shape) == 2:
    axes[1].imshow(warped_moving_image)
else:
    axes[1].imshow(warped_moving_image[...,1])
axes[1].set_title("warped moving image", fontsize=20)

if len(warped_moving_image.shape) == 2:
    axes[2].imshow(fix_img)
else:
    axes[2].imshow(fix_img.max(2))

xs = [x for (x, _, _) in warped_moving_centroids]
ys = [y for (_, y, _) in warped_moving_centroids]


# axes[1].scatter(ys, xs, s=5, c='r')


xs = [x for (x, _, _) in fix_labs if x >= 0]
ys = [y for (_, y, _) in fix_labs if y >= 0]

axes[2].set_title("fixed image", fontsize=20)
# axes[2].scatter(xs, ys, s=5, c='g')
# axes[2].set_xlim(0, 120)
# axes[2].set_ylim(0, 284)
# axes[1].invert_yaxis()
# axes[2].invert_yaxis()
# Out:
# Text(0.5, 1.0, 'fixed image')
